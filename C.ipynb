# %%
# %matplotlib inline
import BET
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]

# %%
data = BET.readIsothermFromCSVFile("C.csv")
BET.isothermProperties(data)
BET.plotIsotherm(data)
# Out:
# Number of data points: 52
# Minimal value of P/P°: 0.0038
# Maximal value of P/P°: 0.9998
# Minimal value of uptake: 196.3
# Maximal value of uptake: 606.0

# %%
BET.plotBET(data, 0.6, 0.1, 0.3)
# Out:
# ✅ C = 22.62 is positive
# ✅ nmono = 464.04 is within BET range (up to 567.34)
# 🔴 Rouquerol plot should be increasing in fit range
# R^2 = 0.9345
#
# Surface area = 2019.760 m^2/g

# %%
BET.plotBET(data, 0.3, 0.001, 0.1)
# Out:
# ✅ C = 342.33 is positive
# ✅ nmono = 360.49 is within BET range (up to 391.11)
# ✅ Rouquerol plot increasing in fit range
# R^2 = 0.9998
#
# Surface area = 1569.072 m^2/g
