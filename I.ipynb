# %%
# %matplotlib inline
import BET
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]

# %%
data = BET.readIsothermFromCSVFile("I.csv")
BET.isothermProperties(data)
BET.plotIsotherm(data)
# Out:
# Number of data points: 62
# Minimal value of P/P°: 0.0000
# Maximal value of P/P°: 0.9929
# Minimal value of uptake: 13.3
# Maximal value of uptake: 378.2

# %%
BET.plotBET(data, 0.6, 0.1, 0.3)
# Out:
# 🔴 C = -43.34 should be positive
# ✅ nmono = 177.53 is within BET range (up to 252.77)
# 🔴 Rouquerol plot should be increasing in fit range
# R^2 = 0.9975
#
# Surface area = 772.719 m^2/g

# %%
BET.plotBET(data, 0.15, 0.001, 0.05)
# Out:
# ✅ C = 625.24 is positive
# ✅ nmono = 206.63 is within BET range (up to 211.10)
# ✅ Rouquerol plot increasing in fit range
# R^2 = 0.9980
#
# Surface area = 899.377 m^2/g
