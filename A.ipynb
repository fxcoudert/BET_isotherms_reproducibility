# %%
# %matplotlib inline
import BET
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]

# %%
data = BET.readIsothermFromCSVFile("A.csv")
BET.isothermProperties(data)
BET.plotIsotherm(data)
# Out:
# Number of data points: 70
# Minimal value of P/P°: 0.0000
# Maximal value of P/P°: 0.9984
# Minimal value of uptake: 40.1
# Maximal value of uptake: 562.4

# %%
BET.plotBET(data, 0.6, 0.1, 0.3)
# Out:
# 🔴 C = -38.32 should be positive
# ✅ nmono = 375.28 is within BET range (up to 538.78)
# 🔴 Rouquerol plot should be increasing in fit range
# R^2 = 0.9974
#
# Surface area = 1633.444 m^2/g

# %%
BET.plotBET(data, 0.05, 0.001, 0.02)
# Out:
# ✅ C = 29123.28 is positive
# ✅ nmono = 489.77 is within BET range (up to 498.48)
# ✅ Rouquerol plot increasing in fit range
# R^2 = 1.0000
#
# Surface area = 2131.748 m^2/g
