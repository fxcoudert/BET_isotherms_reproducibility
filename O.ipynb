# %%
# %matplotlib inline
import BET
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]

# %%
data = BET.readIsothermFromCSVFile("O.csv")
BET.isothermProperties(data)
BET.plotIsotherm(data)
# Out:
# Number of data points: 68
# Minimal value of P/P°: 0.0096
# Maximal value of P/P°: 0.9448
# Minimal value of uptake: 24.3
# Maximal value of uptake: 1619.1

# %%
BET.plotBET(data, 0.6, 0.1, 0.3)
# Out:
# 🔴 C = -42.20 should be positive
# ✅ nmono = 1067.26 is within BET range (up to 1553.96)
# 🔴 Rouquerol plot should be increasing in fit range
# R^2 = 0.9952
#
# Surface area = 4645.349 m^2/g

# %%
BET.plotBET(data, 0.2, 0.02, 0.15)
# Out:
# ✅ C = 59.13 is positive
# ✅ nmono = 1402.68 is within BET range (up to 1457.11)
# ✅ Rouquerol plot increasing in fit range
# R^2 = 0.9988
#
# Surface area = 6105.265 m^2/g
