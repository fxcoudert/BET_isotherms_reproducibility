# %%
# %matplotlib inline
import BET
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]

# %%
data = BET.readIsothermFromCSVFile("H.csv")
BET.isothermProperties(data)
BET.plotIsotherm(data)
# Out:
# Number of data points: 57
# Minimal value of P/P°: 0.0000
# Maximal value of P/P°: 0.9677
# Minimal value of uptake: 2.1
# Maximal value of uptake: 215.3

# %%
BET.plotBET(data, 0.6, 0.1, 0.3)
# Out:
# 🔴 C = -36.42 should be positive
# ✅ nmono = 140.58 is within BET range (up to 200.54)
# 🔴 Rouquerol plot should be increasing in fit range
# R^2 = 0.9985
#
# Surface area = 611.901 m^2/g

# %%
BET.plotBET(data, 0.1, 0.001, 0.02)
# Out:
# ✅ C = 4906.77 is positive
# ✅ nmono = 186.10 is within BET range (up to 187.40)
# ✅ Rouquerol plot increasing in fit range
# R^2 = 1.0000
#
# Surface area = 810.004 m^2/g
