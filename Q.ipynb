# %%
# %matplotlib inline
import BET
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]

# %%
data = BET.readIsothermFromCSVFile("Q.csv")
BET.isothermProperties(data)
BET.plotIsotherm(data)
# Out:
# Number of data points: 106
# Minimal value of P/P°: 0.0001
# Maximal value of P/P°: 0.9942
# Minimal value of uptake: 31.9
# Maximal value of uptake: 1084.4

# %%
BET.plotBET(data, 0.6, 0.1, 0.3)
# Out:
# ✅ C = 8.91 is positive
# ✅ nmono = 807.72 is within BET range (up to 909.47)
# 🔴 Rouquerol plot should be increasing in fit range
# R^2 = 0.9265
#
# Surface area = 3515.651 m^2/g

# %%
BET.plotBET(data, 0.3, 0.05, 0.22)
# Out:
# ✅ C = 20.93 is positive
# ✅ nmono = 628.85 is within BET range (up to 680.91)
# ✅ Rouquerol plot increasing in fit range
# R^2 = 0.9969
#
# Surface area = 2737.122 m^2/g
