# %%
# %matplotlib inline
import BET
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]

# %%
data = BET.readIsothermFromCSVFile("B.csv")
BET.isothermProperties(data)
BET.plotIsotherm(data)
# Out:
# Number of data points: 65
# Minimal value of P/P°: 0.0000
# Maximal value of P/P°: 0.9945
# Minimal value of uptake: 15.3
# Maximal value of uptake: 440.0

# %%
BET.plotBET(data, 0.6, 0.1, 0.3)
# Out:
# 🔴 C = -39.81 should be positive
# ✅ nmono = 232.76 is within BET range (up to 333.00)
# 🔴 Rouquerol plot should be increasing in fit range
# R^2 = 0.9976
#
# Surface area = 1013.091 m^2/g

# %%
BET.plotBET(data, 0.1, 0.001, 0.03)
# Out:
# ✅ C = 1112.18 is positive
# ✅ nmono = 272.72 is within BET range (up to 274.00)
# ✅ Rouquerol plot increasing in fit range
# R^2 = 0.9994
#
# Surface area = 1187.053 m^2/g
