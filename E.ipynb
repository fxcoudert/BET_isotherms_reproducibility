# %%
# %matplotlib inline
import BET
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]

# %%
data = BET.readIsothermFromCSVFile("E.csv")
BET.isothermProperties(data)
BET.plotIsotherm(data)
# Out:
# Number of data points: 152
# Minimal value of P/P°: 0.0000
# Maximal value of P/P°: 0.9922
# Minimal value of uptake: 3.1
# Maximal value of uptake: 627.5

# %%
BET.plotBET(data, 0.6, 0.1, 0.3)
# Out:
# 🔴 C = -31.99 should be positive
# ✅ nmono = 252.10 is within BET range (up to 374.52)
# 🔴 Rouquerol plot should be increasing in fit range
# R^2 = 0.9965
#
# Surface area = 1097.276 m^2/g

# %%
BET.plotBET(data, 0.05, 0.0005, 0.025)
# Out:
# ✅ C = 1418.13 is positive
# ✅ nmono = 318.37 is within BET range (up to 325.27)
# ✅ Rouquerol plot increasing in fit range
# R^2 = 0.9969
#
# Surface area = 1385.739 m^2/g
