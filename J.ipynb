# %%
# %matplotlib inline
import BET
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]

# %%
data = BET.readIsothermFromCSVFile("J.csv")
BET.isothermProperties(data)
BET.plotIsotherm(data)
# Out:
# Number of data points: 74
# Minimal value of P/P°: 0.0000
# Maximal value of P/P°: 0.9880
# Minimal value of uptake: 1.3
# Maximal value of uptake: 1041.6

# %%
BET.plotBET(data, 0.6, 0.1, 0.3)
# Out:
# 🔴 C = -27.95 should be positive
# ✅ nmono = 669.56 is within BET range (up to 1020.29)
# 🔴 Rouquerol plot should be increasing in fit range
# R^2 = 0.9968
#
# Surface area = 2914.330 m^2/g

# %%
BET.plotBET(data, 0.1, 0.01, 0.05)
# Out:
# ✅ C = 733.20 is positive
# ✅ nmono = 930.14 is within BET range (up to 941.93)
# ✅ Rouquerol plot increasing in fit range
# R^2 = 0.9999
#
# Surface area = 4048.525 m^2/g
