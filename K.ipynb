# %%
# %matplotlib inline
import BET
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]

# %%
data = BET.readIsothermFromCSVFile("K.csv")
BET.isothermProperties(data)
BET.plotIsotherm(data)
# Out:
# Number of data points: 70
# Minimal value of P/P°: 0.0000
# Maximal value of P/P°: 0.9834
# Minimal value of uptake: 0.4
# Maximal value of uptake: 641.6

# %%
BET.plotBET(data, 0.6, 0.1, 0.3)
# Out:
# 🔴 C = -24.13 should be positive
# ✅ nmono = 399.02 is within BET range (up to 617.10)
# 🔴 Rouquerol plot should be increasing in fit range
# R^2 = 0.9960
#
# Surface area = 1736.761 m^2/g

# %%
BET.plotBET(data, 0.03, 0.001, 0.025)
# Out:
# ✅ C = 3575.64 is positive
# ✅ nmono = 605.23 is within BET range (up to 608.75)
# 🔴 Rouquerol plot should be increasing in fit range
# R^2 = 0.9999
#
# Surface area = 2634.335 m^2/g
