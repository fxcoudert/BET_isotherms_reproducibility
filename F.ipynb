# %%
# %matplotlib inline
import BET
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]

# %%
data = BET.readIsothermFromCSVFile("F.csv")
BET.isothermProperties(data)
BET.plotIsotherm(data)
# Out:
# Number of data points: 57
# Minimal value of P/P°: 0.0001
# Maximal value of P/P°: 0.9707
# Minimal value of uptake: 0.2
# Maximal value of uptake: 522.7

# %%
BET.plotBET(data, 0.6, 0.1, 0.3)
# Out:
# 🔴 C = -37.70 should be positive
# ✅ nmono = 246.85 is within BET range (up to 351.32)
# 🔴 Rouquerol plot should be increasing in fit range
# R^2 = 0.9985
#
# Surface area = 1074.423 m^2/g

# %%
BET.plotBET(data, 0.15, 0.002, 0.05)
# Out:
# ✅ C = 2400.06 is positive
# ✅ nmono = 316.84 is within BET range (up to 328.59)
# ✅ Rouquerol plot increasing in fit range
# R^2 = 1.0000
#
# Surface area = 1379.068 m^2/g
