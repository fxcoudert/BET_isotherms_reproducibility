# %%
# %matplotlib inline
import BET
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]

# %%
data = BET.readIsothermFromCSVFile("M.csv")
BET.isothermProperties(data)
BET.plotIsotherm(data)
# Out:
# Number of data points: 49
# Minimal value of P/P°: 0.0017
# Maximal value of P/P°: 0.9981
# Minimal value of uptake: 157.6
# Maximal value of uptake: 1851.1

# %%
BET.plotBET(data, 0.6, 0.1, 0.3)
# Out:
# ✅ C = 6.91 is positive
# ✅ nmono = 812.60 is within BET range (up to 848.12)
# 🔴 Rouquerol plot should be increasing in fit range
# R^2 = 0.8387
#
# Surface area = 3536.894 m^2/g

# %%
BET.plotBET(data, 0.3, 0.05, 0.2)
# Out:
# ✅ C = 38.49 is positive
# ✅ nmono = 514.67 is within BET range (up to 584.64)
# ✅ Rouquerol plot increasing in fit range
# R^2 = 0.9995
#
# Surface area = 2240.141 m^2/g
