# %%
# %matplotlib inline
import BET
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]

# %%
data = BET.readIsothermFromCSVFile("D.csv")
BET.isothermProperties(data)
BET.plotIsotherm(data)
# Out:
# Number of data points: 62
# Minimal value of P/P°: 0.0001
# Maximal value of P/P°: 0.9659
# Minimal value of uptake: 0.1
# Maximal value of uptake: 525.4

# %%
BET.plotBET(data, 0.6, 0.1, 0.3)
# Out:
# ✅ C = 263.22 is positive
# ✅ nmono = 378.94 is within BET range (up to 489.94)
# 🔴 Rouquerol plot should be increasing in fit range
# R^2 = 0.9947
#
# Surface area = 1649.354 m^2/g

# %%
BET.plotBET(data, 0.2, 0.001, 0.1)
# Out:
# ✅ C = 217.29 is positive
# ✅ nmono = 355.97 is within BET range (up to 402.64)
# ✅ Rouquerol plot increasing in fit range
# R^2 = 0.9932
#
# Surface area = 1549.407 m^2/g
