# %%
# %matplotlib inline
import BET
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]

# %%
data = BET.readIsothermFromCSVFile("L.csv")
BET.isothermProperties(data)
BET.plotIsotherm(data)
# Out:
# Number of data points: 38
# Minimal value of P/P°: 0.0098
# Maximal value of P/P°: 0.9379
# Minimal value of uptake: 106.7
# Maximal value of uptake: 391.6

# %%
BET.plotBET(data, 0.6, 0.1, 0.3)
# Out:
# ✅ C = 76.11 is positive
# ✅ nmono = 168.32 is within BET range (up to 228.21)
# ✅ Rouquerol plot increasing in fit range
# R^2 = 0.9999
#
# Surface area = 732.619 m^2/g

# %%
BET.plotBET(data, 0.3, 0.01, 0.2)
# Out:
# ✅ C = 111.96 is positive
# ✅ nmono = 164.43 is within BET range (up to 197.24)
# ✅ Rouquerol plot increasing in fit range
# R^2 = 0.9996
#
# Surface area = 715.678 m^2/g
