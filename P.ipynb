# %%
# %matplotlib inline
import BET
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]

# %%
data = BET.readIsothermFromCSVFile("P.csv")
BET.isothermProperties(data)
BET.plotIsotherm(data)
# Out:
# Number of data points: 167
# Minimal value of P/P°: 0.0025
# Maximal value of P/P°: 0.9929
# Minimal value of uptake: 117.3
# Maximal value of uptake: 2573.1

# %%
BET.plotBET(data, 0.6, 0.1, 0.3)
# Out:
# ✅ C = 10.02 is positive
# ✅ nmono = 2251.33 is within BET range (up to 2422.72)
# 🔴 Rouquerol plot should be increasing in fit range
# R^2 = 0.9484
#
# Surface area = 9799.121 m^2/g

# %%
BET.plotBET(data, 0.25, 0.08, 0.2)
# Out:
# ✅ C = 13.79 is positive
# ✅ nmono = 1996.37 is within BET range (up to 2088.28)
# ✅ Rouquerol plot increasing in fit range
# R^2 = 0.9834
#
# Surface area = 8689.375 m^2/g
