# %%
# %matplotlib inline
import BET
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]

# %%
data = BET.readIsothermFromCSVFile("G.csv")
BET.isothermProperties(data)
BET.plotIsotherm(data)
# Out:
# Number of data points: 59
# Minimal value of P/P°: 0.0000
# Maximal value of P/P°: 0.9679
# Minimal value of uptake: 1.5
# Maximal value of uptake: 155.2

# %%
BET.plotBET(data, 0.6, 0.1, 0.3)
# Out:
# 🔴 C = -25.04 should be positive
# ✅ nmono = 98.58 is within BET range (up to 152.22)
# 🔴 Rouquerol plot should be increasing in fit range
# R^2 = 0.9956
#
# Surface area = 429.072 m^2/g

# %%
BET.plotBET(data, 0.05, 0.001, 0.02)
# Out:
# ✅ C = 9507.30 is positive
# ✅ nmono = 143.90 is within BET range (up to 145.59)
# ✅ Rouquerol plot increasing in fit range
# R^2 = 1.0000
#
# Surface area = 626.339 m^2/g
