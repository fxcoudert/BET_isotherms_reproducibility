# %%
# %matplotlib inline
import BET
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]

# %%
data = BET.readIsothermFromCSVFile("N.csv")
BET.isothermProperties(data)
BET.plotIsotherm(data)
# Out:
# Number of data points: 99
# Minimal value of P/P°: 0.0010
# Maximal value of P/P°: 0.9385
# Minimal value of uptake: 134.1
# Maximal value of uptake: 391.1

# %%
BET.plotBET(data, 0.6, 0.1, 0.3)
# Out:
# 🔴 C = -50.37 should be positive
# ✅ nmono = 263.80 is within BET range (up to 375.22)
# 🔴 Rouquerol plot should be increasing in fit range
# R^2 = 0.9908
#
# Surface area = 1148.223 m^2/g

# %%
BET.plotBET(data, 0.15, 0.02, 0.1)
# Out:
# ✅ C = 117.70 is positive
# ✅ nmono = 307.88 is within BET range (up to 317.31)
# ✅ Rouquerol plot increasing in fit range
# R^2 = 0.9984
#
# Surface area = 1340.092 m^2/g

# %%
BET.plotBET(data, 0.15, 0.002, 0.05)
# Out:
# ✅ C = 568.49 is positive
# ✅ nmono = 257.61 is within BET range (up to 269.05)
# ✅ Rouquerol plot increasing in fit range
# R^2 = 0.9990
#
# Surface area = 1121.253 m^2/g
